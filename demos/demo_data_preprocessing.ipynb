# %%
# %load_ext autoreload
# %autoreload 2


import sys
from os.path import join, dirname, abspath,splitext,split
import matplotlib.pyplot as plt
import pandas as pd

config_dir = "../config"
if config_dir not in sys.path:
    sys.path.insert(0, config_dir)

from config import add_to_path, root_dir
add_to_path(join(root_dir, 'src'))

import utils.preprocessing as preprocessing
# Out:
# Added to sys: c:\Users\fauli\OneDrive\Bureau\INSA\quatrième_année\deuxieme_semestre\projet recheche\library\Projet-recheche-INSA-anomaly-detection-librairy-1\src

# %% [markdown]
# # drop_duplicate

# %%
d = {"col1": [1, 2, 2], "col2": [3, 3, 3]}
df = pd.DataFrame(data=d)
df
# Out:
#    col1  col2
# 0     1     3
# 1     2     3
# 2     2     3

# %%
print(preprocessing.drop_duplicate(df))
# Out:
#    col1  col2
# 0     1     3
# 1     2     3

# %% [markdown]
# # drop_nan

# %%
d = {"col1": [1, 2, float('nan')], "col2": [3, 3, 3]}
df = pd.DataFrame(data=d)
df
# Out:
#    col1  col2
# 0   1.0     3
# 1   2.0     3
# 2   NaN     3

# %%
print(preprocessing.drop_nan(df))
# Out:
#    col1  col2
# 0   1.0     3
# 1   2.0     3

# %% [markdown]
# # convert_datetime

# %%
d = {"datetime": ['2026-02-15 15:16:45', '2026-02-15 16:16:45'], "col2": [1, 2]}
df = pd.DataFrame(data=d)
df
# Out:
#               datetime  col2
# 0  2026-02-15 15:16:45     1
# 1  2026-02-15 16:16:45     2

# %%
print(preprocessing.convert_datetime(df))
# Out:
#              datetime  col2
# 0 2026-02-15 15:16:45     1
# 1 2026-02-15 16:16:45     2

# %%
preprocessing.convert_datetime(df).dtypes
# Out:
# datetime    datetime64[ns]
# col2                 int64
# dtype: object

# %% [markdown]
# # renorm_time

# %%
preprocessing.renorm_time(df)
# Out:
#              datetime  col2  time_real
# 0 2026-02-15 15:16:45     1        0.0
# 1 2026-02-15 16:16:45     2     3600.0

# %% [markdown]
# # convert_dict_to_dataframe

# %%
data = {"col_1": [3, 2, 1, 0], "col_2": ["a", "b", "c", "d"]}
df = preprocessing.convert_dict_to_dataframe(data)
df
# Out:
#    col_1 col_2
# 0      3     a
# 1      2     b
# 2      1     c
# 3      0     d

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # clean_dataframe

# %%
d = {"col1": [1, 1, float('nan')], "col2": [3, 3, 3],"col3": [1, 1, 2], "col4": [3, 3, 3],"datetime": ['2026-02-15 15:16:45', '2026-02-15 15:16:45','2026-02-15 17:16:45']}
df = pd.DataFrame(data=d)
df
# Out:
#    col1  col2  col3  col4             datetime
# 0   1.0     3     1     3  2026-02-15 15:16:45
# 1   1.0     3     1     3  2026-02-15 15:16:45
# 2   NaN     3     2     3  2026-02-15 17:16:45

# %%
preprocessing.clean_dataframe(df)
df
# Out:
#    col1  col2  col3  col4            datetime  time_real
# 0   1.0     3     1     3 2026-02-15 15:16:45        0.0
